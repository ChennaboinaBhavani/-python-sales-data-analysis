# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\DELL\Downloads\Project Data.xlsx")
df2=pd.DataFrame(df)

# %%
df2
# Out:
#      OrderID       Date Region     Product     Category  Units_Sold  \
# 0       1001 2025-01-01   East      Laptop  Electronics           5
# 1       1002 2025-01-02   West       Phone  Electronics          10
# 2       1003 2025-01-03  North       Chair    Furniture           8
# 3       1004 2025-01-04  South       Table    Furniture           3
# 4       1005 2025-01-05   East  Headphones  Electronics          15
# ..       ...        ...    ...         ...          ...         ...
# 100     1101 2025-04-11   East      Tablet  Electronics          11
# 101     1102 2025-04-12   West     Printer  Electronics           6
# 102     1103 2025-04-13  North   Bookshelf    Furniture           4
# 103     1104 2025-04-14  South  Smartwatch  Electronics          15
# 104     1105 2025-04-15   East         Bed    Furniture           1
#
#      Unit_Price  Discount (%)
# 0           800            10
# 1           500             5
# 2           120             0
# ...

# %%
df.shape
# Out:
# (105, 8)

# %%
df.head()
# Out:
#    OrderID       Date Region     Product     Category  Units_Sold  Unit_Price  \
# 0     1001 2025-01-01   East      Laptop  Electronics           5         800
# 1     1002 2025-01-02   West       Phone  Electronics          10         500
# 2     1003 2025-01-03  North       Chair    Furniture           8         120
# 3     1004 2025-01-04  South       Table    Furniture           3         300
# 4     1005 2025-01-05   East  Headphones  Electronics          15         100
#
#    Discount (%)
# 0            10
# 1             5
# 2             0
# 3            15
# 4             5

# %%
df.tail()
# Out:
#      OrderID       Date Region     Product     Category  Units_Sold  \
# 100     1101 2025-04-11   East      Tablet  Electronics          11
# 101     1102 2025-04-12   West     Printer  Electronics           6
# 102     1103 2025-04-13  North   Bookshelf    Furniture           4
# 103     1104 2025-04-14  South  Smartwatch  Electronics          15
# 104     1105 2025-04-15   East         Bed    Furniture           1
#
#      Unit_Price  Discount (%)
# 100         335             7
# 101         240             5
# 102         200            10
# 103         255             6
# 104        1400            15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       105 non-null    int64
#  1   Date          105 non-null    datetime64[ns]
#  2   Region        105 non-null    object
#  3   Product       105 non-null    object
#  4   Category      105 non-null    object
#  5   Units_Sold    105 non-null    int64
#  6   Unit_Price    105 non-null    int64
#  7   Discount (%)  105 non-null    int64
# dtypes: datetime64[ns](1), int64(4), object(3)
# memory usage: 6.7+ KB

# %%
df.columns
# Out:
# Index(['OrderID', 'Date', 'Region', 'Product', 'Category', 'Units_Sold',
#        'Unit_Price', 'Discount (%)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# OrderID         0
# Date            0
# Region          0
# Product         0
# Category        0
# Units_Sold      0
# Unit_Price      0
# Discount (%)    0
# dtype: int64

# %%
 ### example of date_column to date time
import pandas as pd

data = {
    'date_column': ['21-02-2026', '15-01-2026', '10-12-2025']
}

df = pd.DataFrame(data)

print("Before Conversion:")
print(df)
print(df.dtypes)
# Out:
# Before Conversion:
#   date_column
# 0  21-02-2026
# 1  15-01-2026
# 2  10-12-2025
# date_column    object
# dtype: object

# %%
df2["Units_Sold"]
# Out:
# 0       5
# 1      10
# 2       8
# 3       3
# 4      15
#        ..
# 100    11
# 101     6
# 102     4
# 103    15
# 104     1
# Name: Units_Sold, Length: 105, dtype: int64

# %%
# create new columns
df2["Total_Sales"]=df2["Units_Sold"]*df2["Unit_Price"]
df2
# Out:
#      OrderID       Date Region     Product     Category  Units_Sold  \
# 0       1001 2025-01-01   East      Laptop  Electronics           5
# 1       1002 2025-01-02   West       Phone  Electronics          10
# 2       1003 2025-01-03  North       Chair    Furniture           8
# 3       1004 2025-01-04  South       Table    Furniture           3
# 4       1005 2025-01-05   East  Headphones  Electronics          15
# ..       ...        ...    ...         ...          ...         ...
# 100     1101 2025-04-11   East      Tablet  Electronics          11
# 101     1102 2025-04-12   West     Printer  Electronics           6
# 102     1103 2025-04-13  North   Bookshelf    Furniture           4
# 103     1104 2025-04-14  South  Smartwatch  Electronics          15
# 104     1105 2025-04-15   East         Bed    Furniture           1
#
#      Unit_Price  Discount (%)  Total_Sales
# 0           800            10         4000
# 1           500             5         5000
# ...

# %%
## discounts_amount
df2["Discount_Amount"]=df2["Total_Sales"]*df2["Discount (%)"]/100
df2
# Out:
#      OrderID       Date Region     Product     Category  Units_Sold  \
# 0       1001 2025-01-01   East      Laptop  Electronics           5
# 1       1002 2025-01-02   West       Phone  Electronics          10
# 2       1003 2025-01-03  North       Chair    Furniture           8
# 3       1004 2025-01-04  South       Table    Furniture           3
# 4       1005 2025-01-05   East  Headphones  Electronics          15
# ..       ...        ...    ...         ...          ...         ...
# 100     1101 2025-04-11   East      Tablet  Electronics          11
# 101     1102 2025-04-12   West     Printer  Electronics           6
# 102     1103 2025-04-13  North   Bookshelf    Furniture           4
# 103     1104 2025-04-14  South  Smartwatch  Electronics          15
# 104     1105 2025-04-15   East         Bed    Furniture           1
#
#      Unit_Price  Discount (%)  Total_Sales  Discount_Amount
# 0           800            10         4000           400.00
# ...

# %%
### final_sales=Total_sales-Discount
df2["Final_Sales"] = df2["Total_Sales"] -df2["Discount_Amount"]
df2
# Out:
#      OrderID       Date Region     Product     Category  Units_Sold  \
# 0       1001 2025-01-01   East      Laptop  Electronics           5
# 1       1002 2025-01-02   West       Phone  Electronics          10
# 2       1003 2025-01-03  North       Chair    Furniture           8
# 3       1004 2025-01-04  South       Table    Furniture           3
# 4       1005 2025-01-05   East  Headphones  Electronics          15
# ..       ...        ...    ...         ...          ...         ...
# 100     1101 2025-04-11   East      Tablet  Electronics          11
# 101     1102 2025-04-12   West     Printer  Electronics           6
# 102     1103 2025-04-13  North   Bookshelf    Furniture           4
# 103     1104 2025-04-14  South  Smartwatch  Electronics          15
# 104     1105 2025-04-15   East         Bed    Furniture           1
#
#      Unit_Price  Discount (%)  Total_Sales  Discount_Amount  Final_Sales
# 0           800            10         4000           400.00      3600.00
# ...

# %%
#### analysis questions
## what is the total revenue
total_revenue = df2["Final_Sales"].sum()
total_revenue
# Out:
# np.float64(201513.65000000002)

# %%
## which region has highest sales
region_sales = df2.groupby("Region")["Final_Sales"].sum().sort_values(ascending=False)
region_sales
# Out:
# Region
# West     53938.30
# South    52256.55
# East     51716.10
# North    43602.70
# Name: Final_Sales, dtype: float64

# %%
## which category perform best
category = df2.groupby("Category")["Final_Sales"].sum().sort_values(ascending=False)
category
# Out:
# Category
# Electronics    147162.85
# Furniture       54350.80
# Name: Final_Sales, dtype: float64

# %%
### pie chart-->category distribution
category_sales = df2.groupby("Category")["Final_Sales"].sum()

plt.pie(category_sales,
        labels=category_sales.index,
        autopct='%1.1f%%',
        startangle=90)
plt.title("Sales Distribution by Category")
plt.show()

# %%
## which category perform best
category=df2.groupby("Category").size()
category
# Out:
# Category
# Electronics    63
# Furniture      42
# dtype: int64

# %%
### pie chart-->category distribution
category=df2.groupby("Category").size()

plt.pie(category,labels=category.index, autopct='%1.1f%%')
plt.title("Sales Distribution by Category")
plt.show()

# %%
##what is average discount
avg_discount=df2["Discount (%)"].mean()
avg_discount
# Out:
# np.float64(7.485714285714286)

# %%
####  what is the monthly sales trend
trend=df2.groupby("Date")["Final_Sales"].sum().sort_values(ascending=False)
trend
# Out:
# Date
# 2025-04-02    8155.75
# 2025-03-18    7828.00
# 2025-03-03    7053.75
# 2025-02-01    6783.00
# 2025-02-16    6545.50
#                ...
# 2025-01-24     600.00
# 2025-01-12     570.00
# 2025-03-25     567.00
# 2025-03-10     552.00
# 2025-03-14     472.50
# Name: Final_Sales, Length: 105, dtype: float64

# %%
df.rename(columns={"Date":"Date_time"},inplace=True)
df
# Out:
#   date_column
# 0  21-02-2026
# 1  15-01-2026
# 2  10-12-2025

# %%
monthly_sales = df.resample("M", on="Date")["Final_Sales"].sum()
print(monthly_sales)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ...

# %%
### which product generates highest profit
profit=df.groupby("Product")["Final_Sales"].sum().sort_values(ascending=False)
profit
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 2
#       1 ### which product generates highest profit
# ----> 2 profit=df.groupby("Product")["Final_Sales"].sum().sort_values(ascending=False)
#       3 profit
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
profit=df.groupby("Product")["Final_Sales"].size().sort_values(ascending=False)
profit
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 profit=df.groupby("Product")["Final_Sales"].size().sort_values(ascending=False)
#       2 profit
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
## correlation between discount_Amount and units sold

# %%
correlation = df["Discount_Amount"].corr(df["Units_Sold"])
correlation
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Discount_Amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[130], line 1
# ...

# %%
## correlation between discount (%) and units sold
correlation = df["Discount (%)"].corr(df["Units_Sold"])
correlation
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Discount (%)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 2
# ...

# %%
### VISUALIZATION TASKS(MATPLOTLIB)
## BAR CHART--> SALES BY REGION
df2=df2.groupby("Region")["Final_Sales"].sum()
plt.figure(figsize=(6,4))
plt.bar(Region,Final_Sales,color="RED")
plt.title("SALES BY REGION")
plt.xlabel("REGION")
plt.ylabel("SALES")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[132], line 3
#       1 ### VISUALIZATION TASKS(MATPLOTLIB)
#       2 ## BAR CHART--> SALES BY REGION
# ----> 3 df2=df2.groupby("Region")["Final_Sales"].sum()
#       4 plt.figure(figsize=(6,4))
#       5 plt.bar(Region,Final_Sales,color="RED")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:245, in SelectionMixin.__getitem__(self, key)
#     243 else:
#     244     if key not in self.obj:
# --> 245         raise KeyError(f"Column not found: {key}")
#     246     ndim = self.obj[key].ndim
#     247     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Final_Sales'

# %%
## BAR CHART--> SALES BY REGION
Region_sales = df.groupby("Region")["Final_Sales"].sum()

plt.figure()
plt.bar((daily_sales.index, daily_sales.values,color="RED",edgecolor="Black")
plt.title("Sales vs Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.show()
# Out:
#   Cell In[133], line 5
#     plt.bar((daily_sales.index, daily_sales.values,color="RED",edgecolor="Black")
#                                                    ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
 ### line chart--> sales Trend over time
daily_sales = df.groupby("Date_time")["Final_Sales"].sum()
plt.plot(daily_sales.index, daily_sales.values)
plt.xlabel("Date_time")
plt.ylabel("Total Sales")
plt.title("Sales Trend Over Time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 2
#       1  ### line chart--> sales Trend over time
# ----> 2 daily_sales = df.groupby("Date_time")["Final_Sales"].sum()
#       3 plt.plot(daily_sales.index, daily_sales.values)
#       4 plt.xlabel("Date_time")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
##3 bar chart--> sales trend over time
daily_sales = df.groupby("Product")["Final_Sales"].sum()
plt.bar(daily_sales.index, daily_sales.values,color="ORANGE",edgecolor="black")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.title("Sales Trend Over Time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[135], line 2
#       1 ##3 bar chart--> sales trend over time
# ----> 2 daily_sales = df.groupby("Product")["Final_Sales"].sum()
#       3 plt.bar(daily_sales.index, daily_sales.values,color="ORANGE",edgecolor="black")
#       4 plt.xlabel("Product")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
## bar chart---> sales by region
region_sales = df.groupby("Region")["Final_Sales"].sum()

plt.figure()
plt.bar(region_sales.index, region_sales.values)
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.title("Sales by Region")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 2
#       1 ## bar chart---> sales by region
# ----> 2 region_sales = df.groupby("Region")["Final_Sales"].sum()
#       4 plt.figure()
#       5 plt.bar(region_sales.index, region_sales.values)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
### pie chart-->category distribution
category_sales = df.groupby("Category")["Final_Sales"].sum()

plt.figure()
plt.pie(category_Sales,
        labels=category_sales.index,
        autopct='%1.1f%%',
        startangle=90)
plt.title("Sales Distribution by Category")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[137], line 2
#       1 ### pie chart-->category distribution
# ----> 2 category_sales = df.groupby("Category")["Final_Sales"].sum()
#       4 plt.figure()
#       5 plt.pie(category_Sales,
#       6         labels=category_sales.index,
#       7         autopct='%1.1f%%',
#       8         startangle=90)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
# ...

# %%
df["Total_sales"].std()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 df["Total_sales"].std()
#
# ...

# %%
## satter plot-> Discount vs units sold
plt.scatter(df['Discount (%)'], df['Units_Sold'])
plt.xlabel("Discount (%)")
plt.ylabel("Units Sold")
plt.title("Discount vs Units Sold")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Discount (%)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[139], line 2
#       1 ## satter plot-> Discount vs units sold
# ...

# %%
## calculate:(Numpy usage Tasks)
## mean sales: "final_sales
sales=df["Final_Sales"].mean()
sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[140], line 3
#       1 ## calculate:(Numpy usage Tasks)
# ...

# %%
df["Total_sales"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 df["Total_sales"].mean()
#
# ...

# %%
df["Final_Sales"].std()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df["Final_Sales"].std()
#
# ...

# %%
df["Total_sales"].var()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total_sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 df["Total_sales"].var()
#
# ...

# %%
df["Final_Sales"].var()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df["Final_Sales"].var()
#
# ...

# %%
mean = df["Final_Sales"].values
total_sales = np.sum(Final_sales)
print("Total Sales:", total_sales)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 mean = df["Final_Sales"].values
# ...

# %%
### Standara deviations
std=df["Final_Sales"].values
std_sales = np.std(Final_sales)
std_sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[109], line 2
#       1 ### Standara deviations
# ...

# %%
### Variance
var= df["Final_Sales"].values
variance= np.var(Final_Sales)
variance
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 2
#       1 ### Variance
# ...

# %%
### Normalize sales data using Numpy

sales = df["Final_Sales"].values
normalized_sales = (Final_sales - np.min(Final_sales)) / (np.max(Final_sales) - np.min(Final_sales))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 3
#       1 ### Normalize sales data using Numpy
# ...

# %%
num = df["Final_Sales"].values
z_scores = (Final_Sales -mean_sales) / std_sales
print(z_scores)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 num = df["Final_Sales"].values
# ...

# %%
import numpy as np

sales = df["Final_Sales"].values

mean_sales = np.mean(Final_sales)
total_sales = np.sum(Final_sales)
std_sales = np.std(Final_sales)
variance_sales = np.var(Final_sales)

normalized_sales = (Final_sales - np.min(Final_sales)) / (np.max(Final_sales) - np.min(Final_sales))

z_scores = (Final_sales - mean_sales) / std_sales
outliers = sales[np.abs(z_scores) > 3]

print("Mean:", mean_sales)
print("Total:", total_sales)
print("Std Dev:", std_sales)
print("Variance:", variance_sales)
print("Outliers:", outliers)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Final_Sales'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 3
#       1 import numpy as np
# ...

# %%
## Bonus challaenges
## predict next month sales using liner regression

# %%
S=df.groupby("Category").size()
S
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 S=df.groupby("Category").size()
#       2 S
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
plt.pie(s,labels=s.index,autopct="%1.1f%%")
plt.title ("Category Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 plt.pie(s,labels=s.index,autopct="%1.1f%%")
#       2 plt.title ("Category Distribution")
#       3 plt.show()
#
# NameError: name 's' is not defined

# %%
### dashboard style visualization
plt.subplot(2,2,1)
df.groupby("Region")["Final_Sales"].sum().plot(kind="bar")
plt.title("Sales by category")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 3
#       1 ### dashboard style visualization
#       2 plt.subplot(2,2,1)
# ----> 3 df.groupby("Region")["Final_Sales"].sum().plot(kind="bar")
#       4 plt.title("Sales by category")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...
